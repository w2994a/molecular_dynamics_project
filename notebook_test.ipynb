# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("RES.dat", sep=" ")

# %%
data
# Out:
#       step       t       x_b       x_c       y_c   ene_pot   ene_kin  \
# 0        0  0.0000  1.230000  0.615000  1.375182  0.000000  0.894242
# 1        1  0.0005  1.232277  0.617277  1.377459  0.011511  0.882783
# 2        2  0.0010  1.234521  0.619551  1.379687  0.045214  0.849231
# 3        3  0.0015  1.236698  0.621816  1.381815  0.098677  0.796011
# 4        4  0.0020  1.238776  0.624068  1.383797  0.168045  0.726954
# ...    ...     ...       ...       ...       ...       ...       ...
# 9995  9995  4.9975  1.242738  0.628066  1.383842  0.247160  0.648137
# 9996  9996  4.9980  1.244208  0.630335  1.385650  0.332266  0.563398
# 9997  9997  4.9985  1.245485  0.632573  1.387212  0.417770  0.478255
# 9998  9998  4.9990  1.246551  0.634774  1.388495  0.497915  0.398439
# 9999  9999  4.9995  1.247391  0.636931  1.389472  0.567471  0.329153
#
#        ene_tot      v_xb      v_xc      v_yc       f_xb      f_xc       f_yc  \
# ...

# %%
data.head()
# Out:
#    step       t       x_b       x_c       y_c   ene_pot   ene_kin   ene_tot  \
# 0     0  0.0000  1.230000  0.615000  1.375182  0.000000  0.894242  0.894242
# 1     1  0.0005  1.232277  0.617277  1.377459  0.011511  0.882783  0.894293
# 2     2  0.0010  1.234521  0.619551  1.379687  0.045214  0.849231  0.894446
# 3     3  0.0015  1.236698  0.621816  1.381815  0.098677  0.796011  0.894688
# 4     4  0.0020  1.238776  0.624068  1.383797  0.168045  0.726954  0.894999
#
#        v_xb      v_xc      v_yc       f_xb      f_xc       f_yc           T  \
# 0  4.554917  4.554917  4.554917  -0.000001 -0.000000  -0.000001  300.000000
# 1  4.521201  4.550786  4.504807  -3.875204 -0.474795  -5.759516  296.155621
# 2  4.420694  4.538276  4.355508  -7.676787 -0.963005 -11.400512  284.899932
# 3  4.255282  4.517113  4.110099 -11.335300 -1.469487 -16.806310  267.045556
# 4  4.028033  4.486939  3.773644 -14.784203 -1.998634 -21.865069  243.878231
#
#        acc_xb     acc_xc      acc_yc
# ...

# %%
plt.figure(figsize=(20, 20))
plt.scatter(range(len(data["ene_tot"])), data["ene_tot"])
plt.plot(data["ene_pot"])
plt.plot(data["ene_kin"])
plt.xlim(0, 1000);
